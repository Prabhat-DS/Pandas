# %%
# -- Mysql Task: 
# --     
# --     1. Create a  table attribute dataset and dress dataset
# --     2. Do a bulk load for these two table for respective dataset 
# --     3. read these dataset in pandas as a dataframe 
# --     4. Convert attribute dataset in json format 
# --     5. Store this dataset into mongodb
# --     6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID
# --     7. Write a sql query to find out how many unique dress that we have based on dress id 
# --     8. Try to find out how mnay dress is having recommendation 0
# --     9. Try to find out total dress sell for individual dress id 
# --     10. Try to find out a third highest most selling dress id

# %% [markdown]
# # 1. Create a  table attribute dataset and dress dataset
#
# #.done in Mysql
#
# # 2. Do a bulk load for these two table for respective dataset
#
# #.bulk load of data has been done in MySql by using the import wizard.

# %% [markdown]
#  # 3. read these dataset in pandas as a dataframe

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\prabhat pc\anaconda3\lib\site-packages (8.0.29)
# Collecting protobuf>=3.0.0
#   Downloading protobuf-4.21.5-cp39-cp39-win_amd64.whl (525 kB)
# Installing collected packages: protobuf
# Successfully installed protobuf-4.21.5

# %%
import pymysql
import pandas as pd

# %%
mydb = pymysql.connect(host = "localhost" , user ="root",database='mysql_pandas_task' , passwd = "Pr171219@#" )

# %%
print( mydb)
# Out:
# <pymysql.connections.Connection object at 0x0000014A0163E910>

# %%
atribute = pd.read_sql_query('SELECT * FROM atribute_dataset', mydb)

# %%
atribute.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low       5    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low       0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High       0    L  Automn   o-neck         full
# 3   966005983    Brief  Average       5    L  Spring   o-neck         full
# 4   876339541     cute      Low       5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern_Type  Recommendation
# 0    empire           None    chiffon     ruffles       animal               1
# 1   natural     microfiber       None     ruffles       animal               0
# 2   natural       polyster       None        None        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
dress = pd.read_sql_query('SELECT * FROM dress_dataset', mydb)

# %%
dress.head()
# Out:
#      Dress_ID  29-8-201  31-8-201  09-02-201  09-04-2013  09-06-2013  \
# 0  1006032852      2114      2274       2491        2660        2727
# 1  1212192089       151       275        570         750         813
# 2  1190380701         6         7          7           7           8
# 3   966005983      1005      1128       1326        1455        1507
# 4   876339541       996      1175       1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-9-2013  ...  24-9-2013  26-9-2013  \
# 0        2887        2930        3119       3204  ...       3554       3624
# 1        1066        1164        1558       1756  ...       2710       2942
# 2           8           9          10         10  ...         11         11
# 3        1621        1637        1723       1746  ...       1878       1892
# 4        1559        1570        1638       1655  ...       2032       2156
#
#    28-9-2013  30-9-2013  10-02-2013  10-04-2013  10-06-2013  10-08-2010  \
# 0       3706       3746        3795        3832        3897        3923
# 1       3258       3354        3475        3654        3911        4024
# 2         11         11          11          11          11          11
# 3       1914       1924        1929        1941        1952        1955
# 4       2252       2312        2387        2459        2544        2614
#
#    10-10-2013  10-12-2013
# 0        3985        4048
# 1        4125        4277
# 2          11          11
# 3        1959        1963
# 4        2693        2736
#
# [5 rows x 24 columns]

# %% [markdown]
# # 4. Convert attribute dataset in json format

# %%
atribute1 = atribute.to_json('atribute.json')

# %%
pd.read_json(r'atribute.json')
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low       5     M  Spring     o-neck
# 496   722565148     Sexy      Low       4  free  Summer     o-neck
# 497   532874347   Casual  Average       5     M  Summer     v-neck
# 498   655464934   Casual  Average       5     L  winter  boat-neck
# 499   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# 1          Petal   natural     microfiber        None     ruffles
# 2           full   natural       polyster        None        None
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster        None        None
# 496         full    empire         cotton        None        None
# 497         full    empire         cotton        None        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern_Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496         None               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %% [markdown]
# # 5. Store this dataset into mongodb

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\prabhat pc\anaconda3\lib\site-packages (4.2.0)

# %%
pip install "pymongo[srv]"
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\prabhat pc\anaconda3\lib\site-packages (4.2.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\prabhat pc\anaconda3\lib\site-packages (from pymongo[srv]) (2.2.1)

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://Prabhat:Pr171219@prabhat-cluster0.szwyq.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
db
# Out:
# Database(MongoClient(host=['prabhat-cluster0-shard-00-01.szwyq.mongodb.net:27017', 'prabhat-cluster0-shard-00-00.szwyq.mongodb.net:27017', 'prabhat-cluster0-shard-00-02.szwyq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-3hypw9-shard-0', tls=True), 'test')

# %%
df1 = pd.read_json(r'atribute.json')

# %%
df1
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low       5     M  Spring     o-neck
# 496   722565148     Sexy      Low       4  free  Summer     o-neck
# 497   532874347   Casual  Average       5     M  Summer     v-neck
# 498   655464934   Casual  Average       5     L  winter  boat-neck
# 499   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire           None     chiffon     ruffles
# 1          Petal   natural     microfiber        None     ruffles
# 2           full   natural       polyster        None        None
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster        None        None
# 496         full    empire         cotton        None        None
# 497         full    empire         cotton        None        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern_Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496         None               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
import json

# %%
db1 = client['task24july']

# %%
coll = db1['atribute']

# %%
with open(r"C:\Users\Prabhat PC\atribute.json",'r') as file:
    file_data = json.load(file)

# %%
if isinstance(file_data , list):
    
    coll.insert_many(file_data )
else:
    coll.insert_one(file_data )
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# C:\Users\PRABHA~1\AppData\Local\Temp/ipykernel_9072/2003750070.py in <module>
#       3     coll.insert_many(file_data )
#       4 else:
# ----> 5     coll.insert_one(file_data )
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     619         write_concern = self._write_concern_for(session)
#     620         return InsertOneResult(
# --> 621             self._insert_one(
#     622                 document,
#     623                 ordered=True,
#
# ~\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     560             _check_write_command_response(result)
#     561
# --> 562         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     563
#     564         if not isinstance(doc, RawBSONDocument):
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1446         """Internal retryable write helper."""
#    1447         with self._tmp_session(session) as s:
# -> 1448             return self._retry_with_session(retryable, func, s, None)
#    1449
#    1450     def __eq__(self, other: Any) -> bool:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1319             retryable and self.options.retry_writes and session and not session.in_transaction
#    1320         )
# -> 1321         return self._retry_internal(retryable, func, session, bulk)
#    1322
#    1323     @_csot.apply
#
# ~\anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1351                     session is not None and server.description.retryable_writes_supported
#    1352                 )
# -> 1353                 with self._get_socket(server, session) as sock_info:
#    1354                     max_wire_version = sock_info.max_wire_version
#    1355                     if retryable and not supports_session:
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_socket(self, server, session)
#    1187                 yield session._pinned_connection
#    1188                 return
# -> 1189             with server.get_socket(handler=err_handler) as sock_info:
#    1190                 # Pin this session to the selected server or connection.
#    1191                 if in_txn and server.description.server_type in (
#
# ~\anaconda3\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in get_socket(self, handler)
#    1404             listeners.publish_connection_check_out_started(self.address)
#    1405
# -> 1406         sock_info = self._get_socket(handler=handler)
#    1407
#    1408         if self.enabled_for_cmap:
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in _get_socket(self, handler)
#    1517                 else:  # We need to create a new connection
#    1518                     try:
# -> 1519                         sock_info = self.connect(handler=handler)
#    1520                     finally:
#    1521                         with self._max_connecting_cond:
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in connect(self, handler)
#    1375                 handler.contribute_socket(sock_info, completed_handshake=False)
#    1376
# -> 1377             sock_info.authenticate()
#    1378         except BaseException:
#    1379             sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in authenticate(self)
#     867             creds = self.opts._credentials
#     868             if creds:
# --> 869                 auth.authenticate(creds, self)
#     870             self.ready = True
#     871             if self.enabled_for_cmap:
#
# ~\anaconda3\lib\site-packages\pymongo\auth.py in authenticate(credentials, sock_info)
#     547     mechanism = credentials.mechanism
#     548     auth_func = _AUTH_MAP[mechanism]
# --> 549     auth_func(credentials, sock_info)
#
# ~\anaconda3\lib\site-packages\pymongo\auth.py in _authenticate_default(credentials, sock_info)
#     473             return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-256")
#     474         else:
# --> 475             return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#     476     else:
#     477         return _authenticate_scram(credentials, sock_info, "SCRAM-SHA-1")
#
# ~\anaconda3\lib\site-packages\pymongo\auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     239         ]
#     240     )
# --> 241     res = sock_info.command(source, cmd)
#     242
#     243     parsed = _parse_scram_response(res["payload"])
#
# ~\anaconda3\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     764             self._raise_if_not_writable(unacknowledged)
#     765         try:
# --> 766             return command(
#     767                 self,
#     768                 dbname,
#
# ~\anaconda3\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     164                 client._process_response(response_doc, session)
#     165             if check:
# --> 166                 helpers._check_command_response(
#     167                     response_doc,
#     168                     sock_info.max_wire_version,
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     179         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     180
# --> 181     raise OperationFailure(errmsg, code, response, max_wire_version)
#     182
#     183
#
# OperationFailure: bad auth : Authentication failed., full error: {'ok': 0, 'errmsg': 'bad auth : Authentication failed.', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
#  # 6. in sql task try to perform left join operation with attrubute dataset and dress dataset on column Dress_ID

# %%
pd.merge(atribute,dress, how= "left", on = "Dress_ID")
#in MySql:-
#select * from atribute_dataset left join dress_dataset on atribute_dataset.Dress_ID= dress_dataset.Dress_ID
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low       5     M  Summer     o-neck
# 1    1212192089   Casual      Low       0     L  Summer     o-neck
# 2    1190380701  vintage     High       0     L  Automn     o-neck
# 3     966005983    Brief  Average       5     L  Spring     o-neck
# 4     876339541     cute      Low       5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 545   722565148     Sexy      Low       4  free  Summer     o-neck
# 546   722565148     Sexy      Low       4  free  Summer     o-neck
# 547   532874347   Casual  Average       5     M  Summer     v-neck
# 548   655464934   Casual  Average       5     L  winter  boat-neck
# 549   919930954   Casual      Low       4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  ... 24-9-2013 26-9-2013 28-9-2013  \
# 0      sleevless    empire           None  ...    3554.0    3624.0    3706.0
# 1          Petal   natural     microfiber  ...    2710.0    2942.0    3258.0
# 2           full   natural       polyster  ...      11.0      11.0      11.0
# 3           full   natural           silk  ...    1878.0    1892.0    1914.0
# 4      butterfly   natural  chiffonfabric  ...    2032.0    2156.0    2252.0
# ..           ...       ...            ...  ...       ...       ...       ...
# 545         full    empire         cotton  ...     859.0       0.0     882.0
# 546         full    empire         cotton  ...     859.0     866.0     882.0
# 547         full    empire         cotton  ...     616.0     597.0     586.0
# 548    sleevless    empire           silk  ...     257.0     256.0     255.0
# 549        short    empire         cotton  ...     628.0     632.0     639.0
#
#      30-9-2013  10-02-2013  10-04-2013  10-06-2013  10-08-2010  10-10-2013  \
# 0       3746.0      3795.0      3832.0      3897.0      3923.0      3985.0
# 1       3354.0      3475.0      3654.0      3911.0      4024.0      4125.0
# 2         11.0        11.0        11.0        11.0        11.0        11.0
# 3       1924.0      1929.0      1941.0      1952.0      1955.0      1959.0
# 4       2312.0      2387.0      2459.0      2544.0      2614.0      2693.0
# ..         ...         ...         ...         ...         ...         ...
# 545        0.0         0.0         0.0       906.0         0.0         0.0
# 546      888.0       895.0       898.0       906.0       913.0       919.0
# 547      569.0       561.0       555.0       551.0       546.0       535.0
# 548      254.0       253.0       250.0       249.0       249.0       249.0
# 549      645.0       651.0       655.0       660.0       668.0       674.0
#
#      10-12-2013
# 0        4048.0
# 1        4277.0
# 2          11.0
# 3        1963.0
# 4        2736.0
# ..          ...
# 545       931.0
# 546       931.0
# 547       520.0
# 548       248.0
# 549       680.0
#
# [550 rows x 37 columns]

# %%
# --     7. Write a sql query to find out how many unique dress that we have based on dress id 


atribute["Dress_ID"].count()
# Out:
# 500

# %%
len(atribute["Dress_ID"].unique())
# Out:
# 475

# %%
# --     8. Try to find out how mnay dress is having recommendation 0
atribute.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low       5    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low       0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High       0    L  Automn   o-neck         full
# 3   966005983    Brief  Average       5    L  Spring   o-neck         full
# 4   876339541     cute      Low       5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern_Type  Recommendation
# 0    empire           None    chiffon     ruffles       animal               1
# 1   natural     microfiber       None     ruffles       animal               0
# 2   natural       polyster       None        None        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
sum(atribute.Recommendation==0)
# Out:
# 290

# %%
# --     9. Try to find out total dress sell for individual dress id 
(dress.set_index('Dress_ID')).sum(axis=1)
# Out:
# Dress_ID
# 1006032852    75979
# 1212192089    52256
# 1190380701      223
# 966005983     39691
# 876339541     44077
#               ...
# 713391965      8915
# 722565148     17508
# 532874347     12606
# 655464934      5167
# 919930954     12312
# Length: 498, dtype: int64

# %%
# --     10. Try to find out a third highest most selling dress id 
d=(dress.set_index('Dress_ID')).sum(axis=1)
d.sort_values(ascending=False)


# third highest most selling dress id:-1006032852
# Out:
# Dress_ID
# 629131530     155927
# 735635595      91556
# 1006032852     75979
# 749031896      75346
# 737538048      57543
#                ...
# 1139064593        20
# 898316315         20
# 703395323         20
# 1124754999        19
# 907669618          4
# Length: 498, dtype: int64
